# %%
from c3s_smaccl import process, readConfig
from luts.luts import read_mlut
from smaccl import Smaccl
# Out:
# /home/applis/anaconda/envs/py3v5.1/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
configfile = './c3s_config.cfg'
config = readConfig(configfile)
dem_lut = read_mlut(config['dem'])

# %%
S = Smaccl('CPU')
process(config, dem_lut, S)

# %%
# %pylab inline
import xarray
res = xarray.open_dataset(config['output'])
imshow(res['TOC_Oa02'], vmax=0.1, vmin=0, cmap='jet')
colorbar()
